# %%
import pandas as pd

# %%
fname = 'data/orig_src/Africa_1997-2020_Feb08.xlsx'

# %%
df = pd.read_excel(fname)

# %% [markdown]
# ![image](pics_for_presentation/acled.png)

# %%
df.head()
# Out:
#    ISO EVENT_ID_CNTY  EVENT_ID_NO_CNTY EVENT_DATE  YEAR  TIME_PRECISION  \
# 0   12          ALG1                 1 1997-01-01  1997               1
# 1   12          ALG2                 2 1997-01-02  1997               1
# 2   12          ALG3                 3 1997-01-03  1997               1
# 3   12          ALG4                 4 1997-01-04  1997               1
# 4   12          ALG5                 5 1997-01-05  1997               1
#
#                    EVENT_TYPE SUB_EVENT_TYPE                    ACTOR1  \
# 0  Violence against civilians         Attack  GIA: Armed Islamic Group
# 1  Violence against civilians         Attack  GIA: Armed Islamic Group
# 2  Violence against civilians         Attack  GIA: Armed Islamic Group
# 3  Violence against civilians         Attack  GIA: Armed Islamic Group
# 4  Violence against civilians         Attack  GIA: Armed Islamic Group
#
#   ASSOC_ACTOR_1  ...  ADMIN3       LOCATION LATITUDE  LONGITUDE  \
# ...

# %%
fname2 = 'data/orig_src/social_data.csv'
df2 = pd.read_csv(fname2, index_col=0)

# %% [markdown]
# ![image](pics_for_presentation/afdb.png)

# %%
df2.head()
# Out:
#       CountryName Country                                      IndicatorName  \
# 52084    Cameroon     CMR  Central government, Fiscal Balance (Current US $)
# 52085    Cameroon     CMR  Central government, Fiscal Balance (Current US $)
# 52086    Cameroon     CMR  Central government, Fiscal Balance (Current US $)
# 52087    Cameroon     CMR  Central government, Fiscal Balance (Current US $)
# 52088    Cameroon     CMR  Central government, Fiscal Balance (Current US $)
#
#              Units  Scale Frequency        Date         Value
# 52084  current US$      1         A  1997-01-01 -3.233041e+08
# 52085  current US$      1         A  1998-01-01 -3.604077e+08
# 52086  current US$      1         A  1999-01-01 -2.971021e+08
# 52087  current US$      1         A  2000-01-01  4.082743e+08
# 52088  current US$      1         A  2001-01-01  1.242385e+08

# %%
fname3 = 'data/acled_social_iso3_timelag_labeled.csv'
df3 = pd.read_csv(fname3, index_col=0)

# %% [markdown]
# ![image](pics_for_presentation/dataset.jpg)

# %%
df3.head()
# Out:
#   EVENT_DATE_MONTH  COUNTRY  Battles  Explosions/Remote violence  Protests  \
# 0          1997-07  Algeria      0.0                         1.0       0.0
# 1          1997-08  Algeria      1.0                         1.0       0.0
# 2          1997-09  Algeria      0.0                         0.0       0.0
# 3          1997-10  Algeria      0.0                         1.0       0.0
# 4          1997-11  Algeria      0.0                         0.0       0.0
#
#    Riots  Strategic developments  Violence against civilians  FATALITIES  \
# 0    0.0                     0.0                        16.0       374.0
# 1    0.0                     0.0                        13.0       665.0
# 2    0.0                     0.0                        10.0       346.0
# 3    0.0                     0.0                        11.0       233.0
# 4    0.0                     0.0                         5.0       115.0
#
#      YEAR  ...  FATALITIES_4_month_ago  Battles_5_month_ago  \
# ...
